# %% [markdown]
# # Get Wikidata items (=resource data)
#
# We query the `itemLabel` (`rdfs:label`) of botanist person names and also the `altLabel` (`skol:altLabel`), i.e. “also known as …” or the name aliases — work year period begin (`wyb`) yielded hardly any useful data and was therefore removed for the time being. If you want to query also other language sources please adjust the SPARQL query

# %%
# !pip install sparqlwrapper

import sys
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import re
import time # time.sleep(1)


explain_and_show_the_data = True
this_timestamp_for_data=20260210 # (datetime.today().strftime('%Y%m%d')) # '%Y%m%d_%H%M'
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try 'pacman -S
#     python-xyz', where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Arch-packaged Python package,
#     create a virtual environment using 'python -m venv path/to/venv'.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip.
#
#     If you wish to install a non-Arch packaged Python application,
#     it may be easiest to use 'pipx install xyz', which will manage a
#     virtual environment for you. Make sure you have python-pipx
#     installed via pacman.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.

# %% [markdown]
# ## Query Wikidata function
#
# The function takes a SPARQL query string as its argument. It will run the SPARQL query and return the result as a data frame

# %%
# def query_wikidata(query):
#     endpoint_url = "https://query.wikidata.org/sparql"
# 
#     def get_results(endpoint_url, query):
#         user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
#         # TODO adjust user agent; see https://w.wiki/CX6
#         sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
#         sparql.setQuery(query)
#         sparql.setReturnFormat(JSON)
#         return sparql.query().convert()
# 
#     results = get_results(endpoint_url, query)
# 
#     raw = pd.json_normalize(results["results"]["bindings"])
# 
#     thisdf = raw.filter(regex="\\.value$")
#     thisdf = thisdf.rename(columns=lambda x: re.sub('\\.value$','',x))
#     
#     if 'orcid' not in thisdf.columns:
#         thisdf['orcid'] = None
#     # if 'wye' not in thisdf.columns:
#     #     thisdf['wye'] = None
#     # if 'au_dict_bio' not in thisdf.columns:
#     #     thisdf['au_dict_bio'] = None
#     
#     # order columns so that they are always in the same order
#     # sparql_cols = ['item', 'itemLabel', 'orcid', 'viaf', 'isni', 'harv', 'ipni', 'abbr', 'bionomia_id', 'yob', 'yod', 'wyb', 'wye']
#     sparql_cols = ['item', 'itemLabel', 'altLabel', 'altLabel_lang', 'abbr', 'yob', 'yod', 'orcid', 'viaf', 'isni', 'harv', 'ipni', 'bionomia_id']
#     thisdf = thisdf[sparql_cols]
#     
#     # for col in list(filter(lambda x: x != 'yob' and x != 'yod', sparql_cols)):
#     #     thisdf[col].astype('string')    
#     return thisdf

def query_wikidata_paged_to_file(base_query, filename, is_append=False, limit=500):
    """
    base_query: The SPARQL string with {sql_paged_part}
    filename: The complete path to the target file (including global timestamp)
    is_append: If true, the file is not deleted and no header is written.
    limit: sparql query LIMIT
    """
    endpoint_url = "https://query.wikidata.org/sparql"
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setReturnFormat(JSON)

    # Only delete if we are NOT in append mode
    if not is_append and os.path.exists(filename):
        os.remove(filename)
        print(f"Old file deleted: {filename}")
    
    # Only write header if we are starting a NEW file
    write_header = not is_append 
    
    # all_chunks = []
    offset = 0
    has_more = True
    
    # Columns that finally want to be used
    sparql_cols = ['item', 'itemLabel', 'altLabel', 'altLabel_lang', 'abbr', 'yob', 'yod', 'orcid', 'viaf', 'isni', 'harv', 'ipni', 'bionomia_id']

    print(f"Store data in: {filename}")
    
    while has_more:
        # IMPORTANT: query should also have ORDER BY ?item in it that the chunks fit together seamlessly
        paged_part = f"LIMIT {limit} OFFSET {offset}"
        paged_query = base_query.replace("{sql_paged_part}", paged_part)
        print(f"Wikidata retrieval in progress (offset: {offset})...", end="")
        
        success = False
        max_retries = 3
        
        # INTERNAL RETRY LOOP
        for attempt in range(max_retries):
            try:
                sparql.setQuery(paged_query)
                results = sparql.query().convert()
                bindings = results["results"]["bindings"]
                success = True
                break  # Success: Out of the retry loop
            except Exception as e:
                wait_time = (attempt + 1) * 10 # 10s, 20s, 30s of waiting
                print(f"Error at offset {offset} (trying {attempt+1}/{max_retries}): {e}")
                if attempt < max_retries - 1:
                    print(f"Wait {wait_time}s for retry...")
                    time.sleep(wait_time)
                else:
                    print(f"Critical error: Maximum of {max_retries} attempts reached.")
                    # Optional: Instead of ‘raise’, one could use ‘has_more = False; break’ here
                    # to at least save the chunks so far.
                    raise e 

        if not success:
            break

        # PROCESSING OF THE CHUNK
        if not bindings:
            has_more = False
            break
        
        raw = pd.json_normalize(bindings)
        chunk_df = raw.filter(regex="\\.value$")
        chunk_df = chunk_df.rename(columns=lambda x: re.sub('\\.value$', '', x))
        
        for col in sparql_cols:
            if col not in chunk_df.columns:
                chunk_df[col] = None
        
        chunk_df = chunk_df[sparql_cols]

        # WRITING DIRECTLY TO DISK (Append mode)
        # We use TSV so that commas in the old labels do not cause column errors
        chunk_df.to_csv(
            filename, 
            sep='\t', 
            index=False, 
            mode='a', 
            header=write_header, 
            encoding='utf-8'
        )
                
        # RAM protection: We do NOT store chunk_df in a list!
        # The memory is automatically freed in the next loop iteration.        
        print(f" – progress at offset {offset}: items appended in file.")
        write_header = False # Write header only the first time
        
        if len(bindings) < limit:
            has_more = False
        else:
            offset += limit
            time.sleep(1.5) # Slightly more generous fair use pause
            
    if is_append:
        print(f"\nDone appending of data. File is ready: {this_output_file}")
    else:
        print(f"\nDone. File is ready: {this_output_file}")
        
    return this_output_file

# %% [markdown]
# ## SPARQL queries
#
# Because wildcard search against item label in Wikidata are very slow and generally time out, we run a number of searches on the presence of relavant identifiers.
#
# SPARQL queries courtesy of Mathias Dillen, Botanic Garden Meise: https://github.com/matdillen/STSM-wikidata-people/blob/master/collectormatching.Rmd. I have changed them slightly by removing the identifier the presence of which is queried on from the SELECT clause and adding the Harvard Index of Botanists ID (P6264), IPNI ID (P586) and IPNI Standard Form (P428). This way all queries return the same terms and no data will be lost when duplicates are removed. The added terms will be valuable for verifying matches later on.
#
# …
#
# Tecnical notes: refactor from bloodhount to bionomia
#
# ### “Biologists” in general
#
# For instance: Walter G. Berendsohn (https://www.wikidata.org/wiki/Q54499411) is described as:
#
# - occupation: researcher, botanist
#
# … and we could try to query him, or biologist in general, by using the relation that a botanist should be a subproperty of working in the field of biology, however it retrieves also "horse breeder", "physiologist" aso. that are primarily not of interest and would give a lot of data noise. In theory to get all biologist we would ask like:
#
# - occupation (P106)/subproperty of (P279) = is biologist (Q864503) or
# - occupation (P106)/subproperty of (P279) = is biology (Q420) or
# - field of work (P101)/subproperty of (P279) = is biologist (Q864503) or
# - field of work (P101)/subproperty of (P279) = is biology (Q420)
#
# … and the query to get occupation ~ biologist:
#
#     ?item wdt:P31 wd:Q5 .
#     ?item p:P106 ?statement_occupation_biologist.
#     ?statement_occupation_biologist (ps:P106/(wdt:P279*)) wd:Q864503.
#     # gets time out, could be cut into parts with LIMIT and OFFSET perhaps
#
# - Occupation in biology gets 315 hits (17.5.2023) many "horse breeder" "racehorse owner" — not helpful.
#
# Queries `occupation_biologist`, `fieldofwork_biology` is perhaps too broad (also with time out), so we try to narrow it to botanist
#
# ### Get Botanists
#
# To query biologists results in too large a number of names, which is unsuitable for comparing botanists, for example, so it was decided to limit the query to the lowest possible occupational branch, i.e. the occupational title botanist, the query would request something like:
#
# - occupation (P106)/subproperty of (P279) = is botanist (Q2374149) or
# - field of work (P101)/subproperty of (P279) = is botanist (Q2374149)

# %%
basequeries = {}

basequeries['occupation_botanist'] = """

SELECT DISTINCT ?item ?itemLabel ?altLabel ?altLabel_lang ?abbr 
    # ?yob ?yod
    # ?orcid ?viaf ?isni ?harv ?ipni ?bionomia_id WHERE {
    # First define only the basic set
    {
        SELECT DISTINCT ?item WHERE {
            # ?item wdt:P31 wd:Q5 ;
            p:P106 ?statement_occupation_botanist.
            # ?statement_occupation_botanist (ps:P106) wd:Q2374149.
            # ?statement_occupation_botanist (ps:P106/(wdt:P279*)) wd:Q2374149.
        } ORDER BY ?item {sql_paged_part}
        # Order important for consistent chunks
        # sql_paged_part Python will insert LIMIT and OFFSET here later see query_wikidata_paged()      
    }
    # Only then add the optional information
    OPTIONAL { ?item rdfs:label ?itemLabel . FILTER (lang(?itemLabel) IN("en", "de", "ru") ) }
    OPTIONAL { ?item skos:altLabel ?altLabel . FILTER (lang(?altLabel) IN("en", "de", "ru" ) ) 
        BIND( lang(?altLabel) as ?altLabel_lang )
    }
    OPTIONAL { ?item wdt:P496 ?orcid . }
    OPTIONAL { ?item wdt:P214 ?viaf . }
    OPTIONAL { ?item wdt:P213 ?isni . }
    OPTIONAL { ?item wdt:P6264 ?harv . }
    OPTIONAL { ?item wdt:P586 ?ipni . }
    OPTIONAL { ?item wdt:P428 ?abbr . }
    OPTIONAL { ?item wdt:P6944 ?bionomia_id . }
    OPTIONAL { ?item wdt:P569 ?dob . BIND(YEAR(?dob) as ?yob) }
    OPTIONAL { ?item wdt:P570 ?dod . BIND(YEAR(?dod) as ?yod) }
}
"""

### Bionomia ID (P6944)

basequeries['bionomia_id'] = """
SELECT DISTINCT ?item ?itemLabel ?altLabel ?altLabel_lang ?abbr 
    # ?yob ?yod
    # ?orcid ?viaf ?isni ?harv ?ipni ?bionomia_id WHERE {
    # First define only the basic set
    {
      SELECT DISTINCT ?item WHERE {
        # ?item wdt:P31 wd:Q5 . # Q5 human
        # ?item wdt:P6944 ?id_of_bionomia_id.
      }  ORDER BY ?item {sql_paged_part}
        # Order important for consistent chunks
        # sql_paged_part Python will insert LIMIT and OFFSET here later see query_wikidata_paged()
    }
    # Only then add the optional information
    OPTIONAL { ?item rdfs:label ?itemLabel . FILTER (lang(?itemLabel) IN("en", "de", "ru") ) }
    OPTIONAL { ?item skos:altLabel ?altLabel . FILTER (lang(?altLabel) IN("en", "de", "ru") ) 
              BIND( lang(?altLabel)  as ?altLabel_lang )
    }
    OPTIONAL { ?item wdt:P496  ?orcid . }
    OPTIONAL { ?item wdt:P214  ?viaf . }
    OPTIONAL { ?item wdt:P213  ?isni . }
    OPTIONAL { ?item wdt:P6264 ?harv . }
    OPTIONAL { ?item wdt:P586  ?ipni . }
    OPTIONAL { ?item wdt:P428  ?abbr . }
    OPTIONAL { ?item wdt:P6944 ?bionomia_id . }
    OPTIONAL { ?item wdt:P569  ?dob . BIND(YEAR(?dob) as ?yob) }
    OPTIONAL { ?item wdt:P570  ?dod . BIND(YEAR(?dod) as ?yod) }
} # resutls 215218 (alltogether including altLabel) on February 10, 2026
"""

# %% [markdown]
# ## Query Data and Create the Data Frame
#
# Run all the SPARQL requests, concatenate the results and drop duplicates

# %%
import os
if not os.path.exists('data'):
    os.makedirs('data')

this_output_file=os.path.join(
    "data", 'wikidata_persons_botanists_{timestamp}.csv'.format(
    timestamp=this_timestamp_for_data
    )
)

print("Start Phase 1: Botanist by profession...")
query_wikidata_paged_to_file(
    base_query=basequeries['occupation_botanist'], 
    filename=this_output_file, 
    limit=500
)

print("Start Phase 2: Botanists according to Bionomia ID...")
query_wikidata_paged_to_file(
    base_query=basequeries['bionomia_id'], 
    filename=this_output_file, 
    is_append=True, # append data to existing file
    limit=1000
)
# Out:
# Start Phase 1: Botanist by profession...
# Old file deleted: data/wikidata_persons_botanists_20260210.csv
# Store data in: data/wikidata_persons_botanists_20260210.csv
# Wikidata retrieval in progress (offset: 0)... – progress at 0: items appended in file.
# Wikidata retrieval in progress (offset: 500)... – progress at 500: items appended in file.
# Wikidata retrieval in progress (offset: 1000)... – progress at 1000: items appended in file.
# Wikidata retrieval in progress (offset: 1500)... – progress at 1500: items appended in file.
# Wikidata retrieval in progress (offset: 2000)... – progress at 2000: items appended in file.
# Wikidata retrieval in progress (offset: 2500)... – progress at 2500: items appended in file.
# Wikidata retrieval in progress (offset: 3000)... – progress at 3000: items appended in file.
# Wikidata retrieval in progress (offset: 3500)... – progress at 3500: items appended in file.
# Wikidata retrieval in progress (offset: 4000)... – progress at 4000: items appended in file.
# Wikidata retrieval in progress (offset: 4500)... – progress at 4500: items appended in file.
# Wikidata retrieval in progress (offset: 5000)... – progress at 5000: items appended in file.
# Wikidata retrieval in progress (offset: 5500)... – progress at 5500: items appended in file.
# Wikidata retrieval in progress (offset: 6000)... – progress at 6000: items appended in file.
# Wikidata retrieval in progress (offset: 6500)... – progress at 6500: items appended in file.
# Wikidata retrieval in progress (offset: 7000)... – progress at 7000: items appended in file.
# Wikidata retrieval in progress (offset: 7500)... – progress at 7500: items appended in file.
# Wikidata retrieval in progress (offset: 8000)... – progress at 8000: items appended in file.
# Wikidata retrieval in progress (offset: 8500)... – progress at 8500: items appended in file.
# Wikidata retrieval in progress (offset: 9000)... – progress at 9000: items appended in file.
# Wikidata retrieval in progress (offset: 9500)... – progress at 9500: items appended in file.
# Wikidata retrieval in progress (offset: 10000)... – progress at 10000: items appended in file.
# Wikidata retrieval in progress (offset: 10500)... – progress at 10500: items appended in file.
# Wikidata retrieval in progress (offset: 11000)... – progress at 11000: items appended in file.
# Wikidata retrieval in progress (offset: 11500)... – progress at 11500: items appended in file.
# Wikidata retrieval in progress (offset: 12000)... – progress at 12000: items appended in file.
# Wikidata retrieval in progress (offset: 12500)... – progress at 12500: items appended in file.
# Wikidata retrieval in progress (offset: 13000)... – progress at 13000: items appended in file.
# Wikidata retrieval in progress (offset: 13500)... – progress at 13500: items appended in file.
# Wikidata retrieval in progress (offset: 14000)... – progress at 14000: items appended in file.
# Wikidata retrieval in progress (offset: 14500)... – progress at 14500: items appended in file.
# Wikidata retrieval in progress (offset: 15000)... – progress at 15000: items appended in file.
# Wikidata retrieval in progress (offset: 15500)... – progress at 15500: items appended in file.
# Wikidata retrieval in progress (offset: 16000)... – progress at 16000: items appended in file.
# Wikidata retrieval in progress (offset: 16500)... – progress at 16500: items appended in file.
# Wikidata retrieval in progress (offset: 17000)... – progress at 17000: items appended in file.
# Wikidata retrieval in progress (offset: 17500)... – progress at 17500: items appended in file.
# Wikidata retrieval in progress (offset: 18000)... – progress at 18000: items appended in file.
# Wikidata retrieval in progress (offset: 18500)... – progress at 18500: items appended in file.
# Wikidata retrieval in progress (offset: 19000)... – progress at 19000: items appended in file.
# Wikidata retrieval in progress (offset: 19500)... – progress at 19500: items appended in file.
# Wikidata retrieval in progress (offset: 20000)... – progress at 20000: items appended in file.
# Wikidata retrieval in progress (offset: 20500)... – progress at 20500: items appended in file.
# Wikidata retrieval in progress (offset: 21000)... – progress at 21000: items appended in file.
# Wikidata retrieval in progress (offset: 21500)... – progress at 21500: items appended in file.
# Wikidata retrieval in progress (offset: 22000)... – progress at 22000: items appended in file.
# Wikidata retrieval in progress (offset: 22500)... – progress at 22500: items appended in file.
# Wikidata retrieval in progress (offset: 23000)... – progress at 23000: items appended in file.
# Wikidata retrieval in progress (offset: 23500)... – progress at 23500: items appended in file.
# Wikidata retrieval in progress (offset: 24000)... – progress at 24000: items appended in file.
# Wikidata retrieval in progress (offset: 24500)... – progress at 24500: items appended in file.
# Wikidata retrieval in progress (offset: 25000)... – progress at 25000: items appended in file.
# Wikidata retrieval in progress (offset: 25500)... – progress at 25500: items appended in file.
# Wikidata retrieval in progress (offset: 26000)... – progress at 26000: items appended in file.
# Wikidata retrieval in progress (offset: 26500)... – progress at 26500: items appended in file.
# Wikidata retrieval in progress (offset: 27000)... – progress at 27000: items appended in file.
# Wikidata retrieval in progress (offset: 27500)... – progress at 27500: items appended in file.
# Wikidata retrieval in progress (offset: 28000)... – progress at 28000: items appended in file.
# Wikidata retrieval in progress (offset: 28500)... – progress at 28500: items appended in file.
# Wikidata retrieval in progress (offset: 29000)... – progress at 29000: items appended in file.
# Wikidata retrieval in progress (offset: 29500)... – progress at 29500: items appended in file.
# Wikidata retrieval in progress (offset: 30000)... – progress at 30000: items appended in file.
# Wikidata retrieval in progress (offset: 30500)... – progress at 30500: items appended in file.
# Wikidata retrieval in progress (offset: 31000)... – progress at 31000: items appended in file.
# Wikidata retrieval in progress (offset: 31500)... – progress at 31500: items appended in file.
# Wikidata retrieval in progress (offset: 32000)... – progress at 32000: items appended in file.
# Wikidata retrieval in progress (offset: 32500)... – progress at 32500: items appended in file.
# Wikidata retrieval in progress (offset: 33000)... – progress at 33000: items appended in file.
# Wikidata retrieval in progress (offset: 33500)... – progress at 33500: items appended in file.
# Wikidata retrieval in progress (offset: 34000)... – progress at 34000: items appended in file.
# Wikidata retrieval in progress (offset: 34500)... – progress at 34500: items appended in file.
# Wikidata retrieval in progress (offset: 35000)... – progress at 35000: items appended in file.
# Wikidata retrieval in progress (offset: 35500)... – progress at 35500: items appended in file.
# Wikidata retrieval in progress (offset: 36000)... – progress at 36000: items appended in file.
# Wikidata retrieval in progress (offset: 36500)... – progress at 36500: items appended in file.
# Wikidata retrieval in progress (offset: 37000)... – progress at 37000: items appended in file.
# Wikidata retrieval in progress (offset: 37500)... – progress at 37500: items appended in file.
# Wikidata retrieval in progress (offset: 38000)... – progress at 38000: items appended in file.
# Wikidata retrieval in progress (offset: 38500)... – progress at 38500: items appended in file.
# Wikidata retrieval in progress (offset: 39000)... – progress at 39000: items appended in file.
# Wikidata retrieval in progress (offset: 39500)... – progress at 39500: items appended in file.
# Wikidata retrieval in progress (offset: 40000)... – progress at 40000: items appended in file.
# Wikidata retrieval in progress (offset: 40500)... – progress at 40500: items appended in file.
# Wikidata retrieval in progress (offset: 41000)... – progress at 41000: items appended in file.
# Wikidata retrieval in progress (offset: 41500)... – progress at 41500: items appended in file.
# Wikidata retrieval in progress (offset: 42000)... – progress at 42000: items appended in file.
# Wikidata retrieval in progress (offset: 42500)... – progress at 42500: items appended in file.
# Wikidata retrieval in progress (offset: 43000)... – progress at 43000: items appended in file.
# Wikidata retrieval in progress (offset: 43500)... – progress at 43500: items appended in file.
# Wikidata retrieval in progress (offset: 44000)... – progress at 44000: items appended in file.
# Wikidata retrieval in progress (offset: 44500)... – progress at 44500: items appended in file.
# Wikidata retrieval in progress (offset: 45000)... – progress at 45000: items appended in file.
# Wikidata retrieval in progress (offset: 45500)... – progress at 45500: items appended in file.
# Wikidata retrieval in progress (offset: 46000)... – progress at 46000: items appended in file.
# Wikidata retrieval in progress (offset: 46500)... – progress at 46500: items appended in file.
# Wikidata retrieval in progress (offset: 47000)... – progress at 47000: items appended in file.
# Wikidata retrieval in progress (offset: 47500)... – progress at 47500: items appended in file.
# Wikidata retrieval in progress (offset: 48000)... – progress at 48000: items appended in file.
# Wikidata retrieval in progress (offset: 48500)... – progress at 48500: items appended in file.
# Wikidata retrieval in progress (offset: 49000)... – progress at 49000: items appended in file.
# Wikidata retrieval in progress (offset: 49500)... – progress at 49500: items appended in file.
# Wikidata retrieval in progress (offset: 50000)... – progress at 50000: items appended in file.
# Wikidata retrieval in progress (offset: 50500)... – progress at 50500: items appended in file.
# Wikidata retrieval in progress (offset: 51000)... – progress at 51000: items appended in file.
# Wikidata retrieval in progress (offset: 51500)... – progress at 51500: items appended in file.
# Wikidata retrieval in progress (offset: 52000)... – progress at 52000: items appended in file.
# Wikidata retrieval in progress (offset: 52500)... – progress at 52500: items appended in file.
# Wikidata retrieval in progress (offset: 53000)... – progress at 53000: items appended in file.
# Wikidata retrieval in progress (offset: 53500)... – progress at 53500: items appended in file.
# Wikidata retrieval in progress (offset: 54000)... – progress at 54000: items appended in file.
# Wikidata retrieval in progress (offset: 54500)... – progress at 54500: items appended in file.
# Wikidata retrieval in progress (offset: 55000)... – progress at 55000: items appended in file.
# Wikidata retrieval in progress (offset: 55500)... – progress at 55500: items appended in file.
# Wikidata retrieval in progress (offset: 56000)... – progress at 56000: items appended in file.
# Wikidata retrieval in progress (offset: 56500)... – progress at 56500: items appended in file.
# Wikidata retrieval in progress (offset: 57000)... – progress at 57000: items appended in file.
# Wikidata retrieval in progress (offset: 57500)... – progress at 57500: items appended in file.
# Wikidata retrieval in progress (offset: 58000)... – progress at 58000: items appended in file.
# Wikidata retrieval in progress (offset: 58500)... – progress at 58500: items appended in file.
# Wikidata retrieval in progress (offset: 59000)... – progress at 59000: items appended in file.
# Wikidata retrieval in progress (offset: 59500)... – progress at 59500: items appended in file.
# Wikidata retrieval in progress (offset: 60000)... – progress at 60000: items appended in file.
# Wikidata retrieval in progress (offset: 60500)... – progress at 60500: items appended in file.
# Wikidata retrieval in progress (offset: 61000)... – progress at 61000: items appended in file.
# Wikidata retrieval in progress (offset: 61500)... – progress at 61500: items appended in file.
# Wikidata retrieval in progress (offset: 62000)... – progress at 62000: items appended in file.
# Wikidata retrieval in progress (offset: 62500)... – progress at 62500: items appended in file.
# Wikidata retrieval in progress (offset: 63000)... – progress at 63000: items appended in file.
# Wikidata retrieval in progress (offset: 63500)... – progress at 63500: items appended in file.
# Wikidata retrieval in progress (offset: 64000)... – progress at 64000: items appended in file.
# Wikidata retrieval in progress (offset: 64500)... – progress at 64500: items appended in file.
# Wikidata retrieval in progress (offset: 65000)... – progress at 65000: items appended in file.
# Wikidata retrieval in progress (offset: 65500)... – progress at 65500: items appended in file.
# Wikidata retrieval in progress (offset: 66000)... – progress at 66000: items appended in file.
# Wikidata retrieval in progress (offset: 66500)... – progress at 66500: items appended in file.
# Wikidata retrieval in progress (offset: 67000)... – progress at 67000: items appended in file.
# Wikidata retrieval in progress (offset: 67500)... – progress at 67500: items appended in file.
# Wikidata retrieval in progress (offset: 68000)... – progress at 68000: items appended in file.
# Wikidata retrieval in progress (offset: 68500)... – progress at 68500: items appended in file.
# Wikidata retrieval in progress (offset: 69000)... – progress at 69000: items appended in file.
# Wikidata retrieval in progress (offset: 69500)... – progress at 69500: items appended in file.
# Wikidata retrieval in progress (offset: 70000)...
# Done. File is ready: data/wikidata_persons_botanists_20260210.csv
# Start Phase 2: Botanists according to Bionomia ID...
# Store data in: data/wikidata_persons_botanists_20260210.csv
# Wikidata retrieval in progress (offset: 0)... – progress at 0: items appended in file.
# Wikidata retrieval in progress (offset: 1000)... – progress at 1000: items appended in file.
# Wikidata retrieval in progress (offset: 2000)... – progress at 2000: items appended in file.
# Wikidata retrieval in progress (offset: 3000)... – progress at 3000: items appended in file.
# Wikidata retrieval in progress (offset: 4000)... – progress at 4000: items appended in file.
# Wikidata retrieval in progress (offset: 5000)... – progress at 5000: items appended in file.
# Wikidata retrieval in progress (offset: 6000)... – progress at 6000: items appended in file.
# Wikidata retrieval in progress (offset: 7000)... – progress at 7000: items appended in file.
# Wikidata retrieval in progress (offset: 8000)... – progress at 8000: items appended in file.
# Wikidata retrieval in progress (offset: 9000)... – progress at 9000: items appended in file.
# Wikidata retrieval in progress (offset: 10000)... – progress at 10000: items appended in file.
# Wikidata retrieval in progress (offset: 11000)... – progress at 11000: items appended in file.
# Wikidata retrieval in progress (offset: 12000)... – progress at 12000: items appended in file.
# Wikidata retrieval in progress (offset: 13000)... – progress at 13000: items appended in file.
# Wikidata retrieval in progress (offset: 14000)... – progress at 14000: items appended in file.
# Wikidata retrieval in progress (offset: 15000)... – progress at 15000: items appended in file.
# Wikidata retrieval in progress (offset: 16000)... – progress at 16000: items appended in file.
# Wikidata retrieval in progress (offset: 17000)... – progress at 17000: items appended in file.
# Wikidata retrieval in progress (offset: 18000)...
# Done appending of data. File is ready: data/wikidata_persons_botanists_20260210.csv
# 'data/wikidata_persons_botanists_20260210.csv'

# %%
df_temp = pd.read_csv(
    this_output_file, 
    sep='\t', 
    encoding='utf-8', 
    low_memory=False  # Prevents warnings for large files with mixed data types
)

print(f"File successfully loaded. Lines: {len(df_temp)}")

if explain_and_show_the_data:
    print("compose itemMatchingLabel = altLabel + itemLabel as name source to match against (itemLabel could serve as skos:perfLabel)")
df_temp['itemMatchingLabel'] = df_temp["altLabel"]
df_temp['itemMatchingLabel'] = df_temp['itemMatchingLabel'].fillna(df_temp["itemLabel"])

col = df_temp.pop("itemMatchingLabel") # place it after itemLabel
df_temp.insert(df_temp.columns.get_loc('itemLabel') + 1, col.name, col)
df_temp.sort_values(by=['item', 'itemLabel', 'itemMatchingLabel'], inplace=True)


cols_drop_duplicates = ['item', 'itemMatchingLabel']
print("drop duplicates for: {}".format(", ".join(cols_drop_duplicates)))
df_temp = df_temp.drop_duplicates(subset=cols_drop_duplicates)

if explain_and_show_the_data:
    print("show data where altLabel was empty (NaN)")
    display(df_temp[df_temp.isnull()['altLabel']].head(10))
    print("show data where altLabel has values")
    display(df_temp[df_temp.notnull()['altLabel']].head(10))
# Out:
# File successfully loaded. Lines: 745732
# compose itemMatchingLabel = altLabel + itemLabel as name source to match against (itemLabel could serve as skos:perfLabel)
# drop duplicates for: item, itemMatchingLabel
# show data where altLabel was empty (NaN)
#                                              item                itemLabel  \
# 535205  http://www.wikidata.org/entity/Q100149196              Russell Cox
# 2966    http://www.wikidata.org/entity/Q100152199               Zhiyong Li
# 2899    http://www.wikidata.org/entity/Q100152296  Alda Pereira da Fonseca
# 2906    http://www.wikidata.org/entity/Q100154933       Thomas R. Sinclair
# 3262    http://www.wikidata.org/entity/Q100250695           Takashi Nakada
# 3276    http://www.wikidata.org/entity/Q100250861           Kiplagat Kotut
# 3277    http://www.wikidata.org/entity/Q100250912              Huiyin Song
# 3278    http://www.wikidata.org/entity/Q100250945                 Yuxin Hu
# 2175    http://www.wikidata.org/entity/Q100269397             Anna Bateson
# 3280    http://www.wikidata.org/entity/Q100277010             Qinghua Wang
#
#               itemMatchingLabel altLabel altLabel_lang    abbr     yob  \
# 535205              Russell Cox      NaN           NaN     NaN     NaN
# 2966                 Zhiyong Li      NaN           NaN     NaN     NaN
# 2899    Alda Pereira da Fonseca      NaN           NaN     NaN  1882.0
# 2906         Thomas R. Sinclair      NaN           NaN     NaN  1944.0
# 3262             Takashi Nakada      NaN           NaN  Nakada  1980.0
# 3276             Kiplagat Kotut      NaN           NaN     NaN     NaN
# 3277                Huiyin Song      NaN           NaN     NaN     NaN
# 3278                   Yuxin Hu      NaN           NaN     NaN     NaN
# 2175               Anna Bateson      NaN           NaN     NaN  1863.0
# 3280               Qinghua Wang      NaN           NaN     NaN     NaN
#
#            yod                orcid      viaf              isni   harv  \
# 535205     NaN  0000-0001-5149-1709       NaN               NaN    NaN
# 2966       NaN                  NaN       NaN               NaN    NaN
# 2899       NaN                  NaN       NaN               NaN    NaN
# 2906       NaN                  NaN  48124632  0000000120371034    NaN
# 3262       NaN                  NaN       NaN               NaN  90077
# 3276       NaN                  NaN       NaN               NaN    NaN
# 3277       NaN                  NaN       NaN               NaN    NaN
# 3278       NaN                  NaN       NaN               NaN    NaN
# 2175    1928.0                  NaN       NaN               NaN    NaN
# 3280       NaN                  NaN       NaN               NaN    NaN
#
#               ipni          bionomia_id
# 535205         NaN  0000-0001-5149-1709
# 2966           NaN                  NaN
# 2899           NaN                  NaN
# 2906           NaN                  NaN
# 3262    20049410-1                  NaN
# 3276           NaN                  NaN
# 3277           NaN                  NaN
# 3278           NaN                  NaN
# 2175           NaN                  NaN
# 3280           NaN                  NaN
# show data where altLabel has values
#                                              item                 itemLabel  \
# 2895    http://www.wikidata.org/entity/Q100142069              Frida Eggens
# 532714  http://www.wikidata.org/entity/Q100146795        Elizabeth Harrison
# 532715  http://www.wikidata.org/entity/Q100146795        Elizabeth Harrison
# 1911    http://www.wikidata.org/entity/Q100156193   Laurence Henry Millener
# 1912    http://www.wikidata.org/entity/Q100156193   Laurence Henry Millener
# 2113    http://www.wikidata.org/entity/Q100156193   Laurence Henry Millener
# 2162    http://www.wikidata.org/entity/Q100156252  Thomas Leonard Lancaster
# 2932    http://www.wikidata.org/entity/Q100156269                Mike Quinn
# 2933    http://www.wikidata.org/entity/Q100156269                Mike Quinn
# 2934    http://www.wikidata.org/entity/Q100156269                Mike Quinn
#
#             itemMatchingLabel               altLabel altLabel_lang    abbr  \
# 2895                   Eggens                 Eggens            de  Eggens
# 532714              Mrs A. H.              Mrs A. H.            en     NaN
# 532715    Mrs Arnold Harrison    Mrs Arnold Harrison            en     NaN
# 1911           L. H. Millener         L. H. Millener            en     NaN
# 1912    Laurie Henry Millener  Laurie Henry Millener            en     NaN
# 2113          Laurie Millener        Laurie Millener            en     NaN
# 2162          T. L. Lancaster        T. L. Lancaster            en     NaN
# 2932         Michael A. Quinn       Michael A. Quinn            de     NaN
# 2933     Michael Andrew Quinn   Michael Andrew Quinn            de     NaN
# 2934                    Quinn                  Quinn            de     NaN
#
#            yob     yod orcid viaf isni harv        ipni bionomia_id
# 2895       NaN     NaN   NaN  NaN  NaN  NaN  20045232-1         NaN
# 532714  1792.0  1834.0   NaN  NaN  NaN  NaN         NaN  Q100146795
# 532715  1792.0  1834.0   NaN  NaN  NaN  NaN         NaN  Q100146795
# 1911    1914.0  2000.0   NaN  NaN  NaN  NaN         NaN  Q100156193
# 1912    1914.0  2000.0   NaN  NaN  NaN  NaN         NaN  Q100156193
# 2113    1914.0  2000.0   NaN  NaN  NaN  NaN         NaN  Q100156193
# 2162    1888.0  1945.0   NaN  NaN  NaN  NaN         NaN  Q100156252
# 2932    1962.0     NaN   NaN  NaN  NaN  NaN         NaN         NaN
# 2933    1962.0     NaN   NaN  NaN  NaN  NaN         NaN         NaN
# 2934    1962.0     NaN   NaN  NaN  NaN  NaN         NaN         NaN

# %%
if explain_and_show_the_data: print("concatenate itemLabel also to itemMatchingLabel")
    
df_itemLabels=df_temp.drop_duplicates(subset=["itemLabel"]).copy()
df_itemLabels['itemMatchingLabel'] = df_itemLabels['itemLabel']

df_matching = pd.concat([df_temp, df_itemLabels], ignore_index=True).drop_duplicates(subset=["item", "itemMatchingLabel"]).sort_values(by=['item', 'itemLabel', 'itemMatchingLabel']).reset_index(drop=True)

lst = [df_itemLabels]
del lst

if explain_and_show_the_data: display(df_matching)
# Out:
# concatenate itemLabel also to itemMatchingLabel
#                                              item            itemLabel  \
# 0       http://www.wikidata.org/entity/Q100142069         Frida Eggens
# 1       http://www.wikidata.org/entity/Q100142069         Frida Eggens
# 2       http://www.wikidata.org/entity/Q100146795   Elizabeth Harrison
# 3       http://www.wikidata.org/entity/Q100146795   Elizabeth Harrison
# 4       http://www.wikidata.org/entity/Q100146795   Elizabeth Harrison
# ...                                           ...                  ...
# 209328     http://www.wikidata.org/entity/Q999670          Erik Flügel
# 209329   http://www.wikidata.org/entity/Q99982783  Dorothy F. Chappell
# 209330   http://www.wikidata.org/entity/Q99982881          Alfredo Faz
# 209331   http://www.wikidata.org/entity/Q99983112        Atsumi Himizu
# 209332   http://www.wikidata.org/entity/Q99983228     Wendy K. Bellows
#
#           itemMatchingLabel             altLabel altLabel_lang      abbr  \
# 0                    Eggens               Eggens            de    Eggens
# 1              Frida Eggens               Eggens            de    Eggens
# 2        Elizabeth Harrison            Mrs A. H.            en       NaN
# 3                 Mrs A. H.            Mrs A. H.            en       NaN
# 4       Mrs Arnold Harrison  Mrs Arnold Harrison            en       NaN
# ...                     ...                  ...           ...       ...
# 209328          Erik Flügel             E.Flügel            ru  E.Flügel
# 209329  Dorothy F. Chappell                  NaN           NaN       NaN
# 209330          Alfredo Faz                  NaN           NaN       NaN
# 209331        Atsumi Himizu                  NaN           NaN       NaN
# 209332     Wendy K. Bellows                  NaN           NaN       NaN
#
#            yob     yod orcid       viaf              isni    harv        ipni  \
# 0          NaN     NaN   NaN        NaN               NaN     NaN  20045232-1
# 1          NaN     NaN   NaN        NaN               NaN     NaN  20045232-1
# 2       1792.0  1834.0   NaN        NaN               NaN     NaN         NaN
# 3       1792.0  1834.0   NaN        NaN               NaN     NaN         NaN
# 4       1792.0  1834.0   NaN        NaN               NaN     NaN         NaN
# ...        ...     ...   ...        ...               ...     ...         ...
# 209328  1934.0  2004.0   NaN  264927543  0000000382392169     NaN     33116-1
# 209329     NaN     NaN   NaN        NaN               NaN     NaN         NaN
# 209330  1863.0  1931.0   NaN        NaN               NaN     NaN         NaN
# 209331     NaN     NaN   NaN        NaN               NaN  107222         NaN
# 209332     NaN     NaN   NaN        NaN               NaN     NaN         NaN
#
#        bionomia_id
# 0              NaN
# 1              NaN
# 2       Q100146795
# 3       Q100146795
# 4       Q100146795
# ...            ...
# 209328         NaN
# 209329         NaN
# 209330   Q99982881
# 209331         NaN
# 209332         NaN
#
# [209333 rows x 14 columns]

# %% [markdown]
# Add columns `surname`, `initials` and `canonical_string`, `canonical_string_fullname` …
#
# Name splitting with https://libraries.io/rubygems/dwc_agent removes all parentheses contents by concept, so we cannot apply it to the following name examples to standardize (clean or parse) names:
#
# - itemLabel: `William J. Bell (entomologist)`
# - itemLabel: `Cecil Stevenson Garnett; d.1950`
# - itemLabel: `William Vernon (c. 1666-1711)`
# - itemLabel: `Hildur von Rettig (Lindberg)`
# - itemLabel: `(Johan) Fredrik(Friedrich) (Eberhard) Svanlund`
# - itemLabel: `[M.] O.K. Poon`
# - itemLabel: `(J.A.A.)M.(H.) Goossens-Fontana`
# - itemLabel: `Thomas Platter the Younger`
#
# … `dwcagent` would parse like this (see David Shorthouses comment in [issue #18 (github.com/bionomia/dwc_agent/)](https://github.com/bionomia/dwc_agent/issues/18#issuecomment-1810976221)):
#
# ```bash
# # https://www.wikidata.org/wiki/Q21610079
# dwcagent '(Johan) Fredrik(Friedrich) (Eberhard) Svanlund' | jq '.'
# ```
# gives
# ```json
# [
#   {
#     "family": "Svanlund",
#     "given": "Johan Fredrik",
#     "suffix": null,
#     "particle": null,
#     "dropping_particle": null,
#     "nick": null,
#     "appellation": null,
#     "title": null
#   }
# ]
# ```

# %%
# add some methods to abbreviate a name word, clean messy name input
# 
# The idea is to get the family name at the end of the string, and swap a reverse name spelling 
# ("family, given name" aso.), so that the call name comes first and the family or clan name 
# comes near the end (as most names are given like this in WikiData)
# TODO deal with “Mrs”, e.g. Mrs Arnold Harrison

def abbr_word(word):
    """
    Return the abbreviation of a word, e.g: Anton → A. or (Lisa) → (L.)

    @param word: a word without spaces
    @return: str an abbreviated word
    """
    if len(word) > 0:
        word = word.strip()
        names_regex_substitution = {
            # generic simple names: Antonio OR (Antonius)
            r"^([^\w\s]*)(\w)\w*([^\w\s\.]*)$": r"\1\2.\3",
            # names having minus: Charles-Jeunet OR (Carl-Jeanet) → CJ. OR (CJ.)
            r"^([^\w\s]*)(\w)\w*[-–—](\w)\w*([^\w\s\.]*)$": r"\1\2\3.\4",
            # names having apostrophe: (Ch'An)
            r"^([^\w\s]*)(\w)\w*['’’´`](\w)\w*([^\w\s\.]*)$": r"\1\2.\4",
            # names having comma: (Eugen,Eugène)
            r"^([^\w\s]*)(\w)\w*[,](\w)\w*([^\w\s\.]*)$": r"\1\2.,\3.\4",
            # names having immediate parentheses: Wilhelmus(Wim)
            r"^(\w)\w*(\()(\w)\w*(\))$": r"\1.\2\3.\4",
            # names having immediate parentheses + comma: Ion(Ioan,Joan)
            r"^(\w)\w*(\()(\w)\w*,(\w)\w*(\))$": r"\1.\2\3.,\4.\5",
            # names having immediate parentheses + an apostrophe: "Chan(Ch'An)"
            r"^(\w)\w*(\()(\w)\w*['’’´`](\w)\w*(\))$": r"\1.\2\3.\5",
            # names having immediate parentheses + minus in the name: 'Ken-Ichiro(Ken-Itirô)'
            r"^([^\w\s]*)(\w)\w*[-–—](\w)\w*([^\w\s\.]*)(\w)\w*[-–—](\w)\w*([^\w\s\.]*)$": r"\1\2\3.\4\5\6.\7",
        }

        for k_search_pattern, v_replace_pattern in names_regex_substitution.items():
            if re.match(k_search_pattern, word, re.IGNORECASE):
                return re.sub(k_search_pattern, v_replace_pattern, word)
        return word
    else:
        return word

def clean_person_name(this_full_name):
    """
    Clean person name from WikiData to get `given + … + family` and not in reverse order `family, given + … `
    
    TODO how to deal with comma and: …, Jr., II., the younger aso. ? (should be considered when splitting on family name)
    
    @requires re
    @param this_full_name: str the name to be cleaned
    @return: str the processed name
    """
    parentheses_words_at_last = [
        'botaniker', 'botanist', 'botanist-1', 'bot.',
        'diatomist',
        'entomologist',
        'instruisto',
        'lehrer',
        'mycologist',
        'taxonomist', 'teacher',
        'zoologist'
    ]
    regex_paranthesis_words = re.compile(r' +\((' + '|'.join(parentheses_words_at_last) + r')\) *$', flags=re.IGNORECASE)

    # delete life time e.g. "… (c. 1534)" or "… (1748-1801)"
    this_full_name = re.sub(r" +\([c. ]*\d+[-–—]*\d+\) *", r"", this_full_name)
    # delete occupations in parentheses
    this_full_name = regex_paranthesis_words.sub(r"", this_full_name)
    # delete noble designations, e.g. “Sir James Nasmyth, 2nd Baronet” → “Sir James Nasmyth”
    this_full_name = re.sub(r" *, +[2]*(1st|2nd|3rd|[4-9]th|[1][0-9]th)[^,]+$", r"", this_full_name)
    # reverse cyrillic simple names: Штейп, Владимир Владимирович → Владимир Владимирович Штейп
    this_full_name = re.sub(r"^([\u0400-\u04FF-]+),\s+([\u0400-\u04FF- ]+)$", r"\2 \1", this_full_name)
    # offset when comma for “, the younger \w+” aso., e.g.: “Peter Joseph, the younger Lenné” → “Peter Joseph Lenné, the younger”
    this_full_name = re.sub(
        r"""
        , \s+ (
            [Tt]he \s+ [Yy]ounger 
            | [Dd]ie \s+ [Jj]üngere 
            | [Dd]er \s+ [Jj]üngere
            | [Dd]ie \s+ [Ää]ltere
            | [Dd]er \s+ [Ää]ltere
            ) (\s+ \w+[-]?\w+)
        $
        """, 
        r"\2, \1", this_full_name, flags=re.VERBOSE
    )
        
    return this_full_name

def simple_namereverse2family_last(this_name_reversed):
    """
    Get the family name or clan name to the last position from names that seem obviously reversed
    
    Draft: it should be applied, after family name splitting was unsuccessful
    @param this_name_reversed:
    @return:
    """
    if len(this_name_reversed) > 0:
        this_name_reversed = this_name_reversed.strip()
        names_regex_substitution = {
            # Baudoin-Bodin, Jacqueline
            # Brennecke, Dorothea
            # Chi, Chün-tao
            # Cormack, R.G.H.
            # Gajón Sánchez, Carlos
            r"^(\w+[-.\s]*\w*[-.\s]*\w*[-.\s]*),\s(\w+[-.\s]*\w*[-.\s]*\w*[-.\s]*)$": r"\2 \1",
            # TODO William E., III, Fox → William E. Fox, III
            r"^(\w+[-.\s]*\w*[-.\s]*\w*[-.\s]*),\s([IVX]+),\s(\w+[-.\s]*\w*[-.\s]*\w*[-.\s]*)$": r"\1 \3, \2",
        }

        for k_search_pattern, v_replace_pattern in names_regex_substitution.items():
            if re.match(k_search_pattern, this_name_reversed, re.IGNORECASE):
                return re.sub(k_search_pattern, v_replace_pattern, this_name_reversed)
        return this_name_reversed
    else:
        return this_name_reversed

regex_split_on_family_name = re.compile(
    r"""
    (?<!,)
    \s+ (
     \w+[-]?\w+, \s+ [Bb]aron[in]*   \s+ [Vv]on \s+ \w+[-]?\w+
    |\w+[-]?\w+, \s+ [Gg]r[aä]f[in]* \s+ [Vv]on \s+ \w+[-]?\w+
    |\w+[-]?\w+, \s+ [Dd]uke         \s+ [Oo]f \s+ \w+[-]?\w+
    |\w+[-]?\w+, \s+ [Dd]uchess      \s+ [Oo]f \s+ \w+[-]?\w+
    |\w+[-]?\w+, \s+ [Cc]ountess     \s+ [Oo]f \s+ \w+[-]?\w+
    |\w+[-]?\w+, \s+ [Mm]archioness  \s+ [Oo]f \s+ \w+[-]?\w+
    |\w+[-]?\w+, \s+ [Dd]uchesse     \s+ [Dd]e \s+ \w+[-]?\w+
    |\w+[-]?\w+, \s+ [Cc]omte        \s+ [Dd]e \s+ \w+[-]?\w+
    |\w+[-]?\w+, \s+ [Cc]omtesse     \s+ [Dd]e \s+ \w+[-]?\w+
    |\w+[-]?\w+, \s+ later           \s+ \w+[-]?\w+
    |\w+[-]?\w+, \s+ [XVI]+[.]?
    |\w+[-]?\w+, \s+ Junior[.]?
    |\w+[-]?\w+, \s+ [JjS]r[.]?
    |\w+[-]?\w+,? \s+ [Tt]he \s+ [Yy]ounger
    |\w+[-]?\w+,? \s+ [Dd]ie \s+ [Jj]üngere
    |\w+[-]?\w+,? \s+ [Dd]er \s+ [Jj]üngere
    |\w+[-]?\w+,? \s+ [Dd]ie \s+ [Ää]ltere
    |\w+[-]?\w+,? \s+ [Dd]er \s+ [Ää]ltere
    |\w['’‘]\w+
    |\w+[-]?\w+
    |\w+\s?\([^()]+\)[.]?
    |\w\w*[.]?[-–—]\w+
    )
    $
    """,
    re.VERBOSE | re.MULTILINE
)

# %%
surname = []
initials = []
canonical = []
canonical_fullname = []

# TODO: use dwcagent on names? Unfortunately it removes all parentheses content

for i, item in df_matching.iterrows():
    thisItemLabelModified = '{}'.format(item['itemMatchingLabel']).strip()
    thisItemLabelModified = clean_person_name(thisItemLabelModified)
    # split at last name part, optionally having parentheses TODO how to deal with Jr., II. aso. 
    # print(thisItemLabelModified)
    nameparts = regex_split_on_family_name.split(thisItemLabelModified)
    if len(nameparts) == 1 and re.findall(r",", thisItemLabelModified):
        # re-iterate through probably reversed names
        thisItemLabelModified = simple_namereverse2family_last(thisItemLabelModified)
        nameparts = regex_split_on_family_name.split(thisItemLabelModified)
    # remove empty/None: ['Friedrich August Marschall von', 'Bieberstein', None, '']
    nameparts = [string for string in nameparts if string]
    if len(nameparts)==1:
        initials.append("") # no beginning name initials per se, only family name
        surname.append("")
        canonical.append(" ".join(nameparts))
        canonical_fullname.append(" ".join(nameparts))
    else:
        surname.append(nameparts[0])
        first_nameparts = re.split('[ ]', nameparts[0])
        first_nameparts = [string for string in first_nameparts if string]
        # print(first_nameparts)
        initials.append(" ".join([abbr_word(w) for w in first_nameparts if len(w) > 0]) )
        canonical.append(" ".join([abbr_word(w) for w in first_nameparts if len(w) > 0]) + " " + nameparts[1])
        # canonical.append(words[-1] + ', ' + ".".join([w[0] for w in words[0:-1] if len(w) > 0]) + '.')
        canonical_fullname.append(" ".join(nameparts))
    
df_matching['surname'] = surname
df_matching['initials'] = initials
df_matching['canonical_string'] = canonical
df_matching['canonical_string_fullname'] = canonical_fullname # should equal itemMatchingLabel

if explain_and_show_the_data: display(df_matching.head())
# Out:
#                                         item           itemLabel  \
# 0  http://www.wikidata.org/entity/Q100142069        Frida Eggens
# 1  http://www.wikidata.org/entity/Q100142069        Frida Eggens
# 2  http://www.wikidata.org/entity/Q100146795  Elizabeth Harrison
# 3  http://www.wikidata.org/entity/Q100146795  Elizabeth Harrison
# 4  http://www.wikidata.org/entity/Q100146795  Elizabeth Harrison
#
#      itemMatchingLabel             altLabel altLabel_lang    abbr     yob  \
# 0               Eggens               Eggens            de  Eggens     NaN
# 1         Frida Eggens               Eggens            de  Eggens     NaN
# 2   Elizabeth Harrison            Mrs A. H.            en     NaN  1792.0
# 3            Mrs A. H.            Mrs A. H.            en     NaN  1792.0
# 4  Mrs Arnold Harrison  Mrs Arnold Harrison            en     NaN  1792.0
#
#       yod orcid viaf isni harv        ipni bionomia_id     surname initials  \
# 0     NaN   NaN  NaN  NaN  NaN  20045232-1         NaN
# 1     NaN   NaN  NaN  NaN  NaN  20045232-1         NaN       Frida       F.
# 2  1834.0   NaN  NaN  NaN  NaN         NaN  Q100146795   Elizabeth       E.
# 3  1834.0   NaN  NaN  NaN  NaN         NaN  Q100146795
# 4  1834.0   NaN  NaN  NaN  NaN         NaN  Q100146795  Mrs Arnold    M. A.
#
#   canonical_string canonical_string_fullname
# 0           Eggens                    Eggens
# 1        F. Eggens              Frida Eggens
# 2      E. Harrison        Elizabeth Harrison
# 3        Mrs A. H.                 Mrs A. H.
# 4   M. A. Harrison       Mrs Arnold Harrison

# %%
# narrow the needed columns down
df_matching = df_matching[[
    'item', 'itemLabel', 
    'surname', 'initials', 'canonical_string', 'canonical_string_fullname',
    'orcid', 'viaf', 'isni', 'harv', 'ipni', 'abbr', 'bionomia_id',
    'yob', 'yod'
    #, 'wyb', 'wye'
]]
df_matching.reset_index(drop=True, inplace=True)

if explain_and_show_the_data: display(df_matching.head())
# Out:
#                                         item           itemLabel     surname  \
# 0  http://www.wikidata.org/entity/Q100142069        Frida Eggens
# 1  http://www.wikidata.org/entity/Q100142069        Frida Eggens       Frida
# 2  http://www.wikidata.org/entity/Q100146795  Elizabeth Harrison   Elizabeth
# 3  http://www.wikidata.org/entity/Q100146795  Elizabeth Harrison
# 4  http://www.wikidata.org/entity/Q100146795  Elizabeth Harrison  Mrs Arnold
#
#   initials canonical_string canonical_string_fullname orcid viaf isni harv  \
# 0                    Eggens                    Eggens   NaN  NaN  NaN  NaN
# 1       F.        F. Eggens              Frida Eggens   NaN  NaN  NaN  NaN
# 2       E.      E. Harrison        Elizabeth Harrison   NaN  NaN  NaN  NaN
# 3                 Mrs A. H.                 Mrs A. H.   NaN  NaN  NaN  NaN
# 4    M. A.   M. A. Harrison       Mrs Arnold Harrison   NaN  NaN  NaN  NaN
#
#          ipni    abbr bionomia_id     yob     yod
# 0  20045232-1  Eggens         NaN     NaN     NaN
# 1  20045232-1  Eggens         NaN     NaN     NaN
# 2         NaN     NaN  Q100146795  1792.0  1834.0
# 3         NaN     NaN  Q100146795  1792.0  1834.0
# 4         NaN     NaN  Q100146795  1792.0  1834.0

# %%
# add custom columns
# df.loc[(df['column_of_interest'] … condition), 'fill_to_column'] = value 
# display(df_matching)

# %%
df_matching["wikidata_link"] = df_matching['item'].apply(lambda thiscol: thiscol.replace('entity', 'wiki')) # needed?
df_matching["orcid_link"] = 'https://orcid.org/' + df_matching['orcid']
    # df_matching.assign(orcid_link=lambda thisdf: 'https://orcid.org/' + str(thisdf['orcid']))
df_matching["harv_link"] = 'https://kiki.huh.harvard.edu/databases/botanist_search.php?mode=details&id=' + df_matching['harv']
    # df_matching.assign(harv_link = lambda thisdf: 'https://kiki.huh.harvard.edu/databases/botanist_search.php?mode=details&id=' + str(thisdf['harv']))
df_matching["ipni_link"] = 'https://www.ipni.org/a/' + df_matching['ipni']
    # df_matching.assign(ipni_link = lambda thisdf: 'https://www.ipni.org/a/' + str(thisdf['ipni']))
df_matching["bionomia_link"] = 'https://bionomia.net/' + df_matching['bionomia_id']
    # df_matching.assign(bionomia_link = lambda thisdf: 'https://bionomia.net/' + str(thisdf['bionomia_id']))

if explain_and_show_the_data: display(df_matching.head())
# Out:
#                                         item           itemLabel     surname  \
# 0  http://www.wikidata.org/entity/Q100142069        Frida Eggens
# 1  http://www.wikidata.org/entity/Q100142069        Frida Eggens       Frida
# 2  http://www.wikidata.org/entity/Q100146795  Elizabeth Harrison   Elizabeth
# 3  http://www.wikidata.org/entity/Q100146795  Elizabeth Harrison
# 4  http://www.wikidata.org/entity/Q100146795  Elizabeth Harrison  Mrs Arnold
#
#   initials canonical_string canonical_string_fullname orcid viaf isni harv  \
# 0                    Eggens                    Eggens   NaN  NaN  NaN  NaN
# 1       F.        F. Eggens              Frida Eggens   NaN  NaN  NaN  NaN
# 2       E.      E. Harrison        Elizabeth Harrison   NaN  NaN  NaN  NaN
# 3                 Mrs A. H.                 Mrs A. H.   NaN  NaN  NaN  NaN
# 4    M. A.   M. A. Harrison       Mrs Arnold Harrison   NaN  NaN  NaN  NaN
#
#          ipni    abbr bionomia_id     yob     yod  \
# 0  20045232-1  Eggens         NaN     NaN     NaN
# 1  20045232-1  Eggens         NaN     NaN     NaN
# 2         NaN     NaN  Q100146795  1792.0  1834.0
# 3         NaN     NaN  Q100146795  1792.0  1834.0
# 4         NaN     NaN  Q100146795  1792.0  1834.0
#
#                              wikidata_link orcid_link harv_link  \
# 0  http://www.wikidata.org/wiki/Q100142069        NaN       NaN
# 1  http://www.wikidata.org/wiki/Q100142069        NaN       NaN
# 2  http://www.wikidata.org/wiki/Q100146795        NaN       NaN
# 3  http://www.wikidata.org/wiki/Q100146795        NaN       NaN
# 4  http://www.wikidata.org/wiki/Q100146795        NaN       NaN
#
#                            ipni_link                    bionomia_link
# 0  https://www.ipni.org/a/20045232-1                              NaN
# 1  https://www.ipni.org/a/20045232-1                              NaN
# 2                                NaN  https://bionomia.net/Q100146795
# 3                                NaN  https://bionomia.net/Q100146795
# 4                                NaN  https://bionomia.net/Q100146795

# %% [markdown]
# ## Save Data

# %%
from datetime import datetime
# write data frame as CSV with a date time

import os
if not os.path.exists('data'):
    os.makedirs('data')

this_output_file=os.path.join(
    "data", 'wikidata_persons_botanists_{timestamp}.csv'.format(
    timestamp=this_timestamp_for_data
    )
)

df_matching.to_csv(this_output_file)

print("Wrote processd data frame into %s (%d kB)" % 
    (this_output_file, os.path.getsize(this_output_file) >> 10 ) # 10000 >> 10 = bitshift operator, to get kilo bytes (10-bits=>1024)
)
# Out:
# Wrote processd data frame into data/wikidata_persons_botanists_20260210.csv (55750 kB)

# %% [markdown]
# ## Documentation
#
# Explanation of columns:
#
# Column | Description
# -|-
# **Wikidata** |
# item | Wikidata Item ID (URL)
# itemLabel | Wikidata Item label
# itemMatchingLabel | the source label to build on surname, initials aso., to against later on; it is the concatenation of itemLabel and altLabel
# altLabel | the name aliases, or skos:altLabel of WikiData
# surname	| Surname; derived from item label
# initials | Initials; derived from item label
# canonical_string | Canonical name string; derived from item label, used for matching
# canonical_string_fullname | Canonical name string including full (given) name; derived from item label, used for matching
# orcid | ORCID ([P496](https://www.wikidata.org/wiki/Property:P496))
# viaf | VIAF ID ([P214](https://www.wikidata.org/wiki/Property:P214))
# isni | ISNI ID ([P213](https://www.wikidata.org/wiki/Property:P496))
# harv | Harvard Index of Botanists ID ([P6264](https://www.wikidata.org/wiki/Property:P6264))
# ipni | IPNI author ID ([P586](https://www.wikidata.org/wiki/Property:P586))
# abbr | botanist author abbreviation (standard form) ([P428](https://www.wikidata.org/wiki/Property:P428))
# bionomia_id | identifier for a collector and/or determiner of natural history specimens, in the Bionomia database ([P6944](https://www.wikidata.org/wiki/Property:P6944))
# yob	| Year of birth (derived from [P569](https://www.wikidata.org/wiki/Property:P569))
# yod	| Year of death (derived from [P496](https://www.wikidata.org/wiki/Property:P570))
# wyb	| Work year period begin ([P2031](https://www.wikidata.org/wiki/Property:P2031))
# wye | Work year period end ([P2032](https://www.wikidata.org/wiki/Property:P2032))
